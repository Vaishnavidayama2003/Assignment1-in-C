# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavidayama2003/Assignment1-in-C/blob/main/Demo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
mylist = [10,20,30]
res = pd.Series(mylist)
print("Series = \n",res)
# Out:
# Series =
#  0    10
# 1    20
# 2    30
# dtype: int64

# %%
import numpy as np
arr = np.array((10,20,30))
print(arr)
print(type(arr))
# Out:
# [10 20 30]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
xpts = np.array([20,10])
ypts = np.array([40,200])
plt.plot(xpts,ypts)
plt.show()
